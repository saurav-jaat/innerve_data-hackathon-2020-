# %% [markdown]
# ---
# # Dumping user wise strengths features train data

# %%
# Loading Libraries
import pandas as pd
import numpy as np
from tabulate import tabulate

from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split as ttsplit

import constants

RANDOM_STATE = constants.RANDOM_STATE

# %%
# Loading training data
df_train = pd.read_csv(constants.OUTPUT_FILE)
print(df_train.shape)
df_train.head()
# Out:
# (1, 43)
#       from-to  userA_id  userB_id  has_common_skills  n_common_skills  \
# 0  888999-222  888999.0     222.0                0.0             -1.0
#
#    has_common_schools  n_common_schools  has_common_industry  \
# 0                 0.0              -1.0                  0.0
#
#    n_common_industry  has_common_company  ...  userB_purpose_id_6  \
# 0               -1.0                 0.0  ...                 0.0
#
#    userB_purpose_id_7  userB_purpose_id_8  userB_purpose_id_9  \
# 0                 0.0                 0.0                 0.0
#
#    userB_purpose_id_10  userB_purpose_id_11  userB_purpose_id_12  \
# 0                  0.0                  0.0                  0.0
#
#    userB_purpose_id_13  userB_purpose_id_14  userB_purpose_id_15
# 0                  0.0                  0.0                  0.0
#
# [1 rows x 43 columns]

# %% [markdown]
# ## Loading Lookup dataFrame

# %%
# Loading skills table to create a lookup to create feature from
df_strengths = pd.read_csv(constants.DATA_PATH+'user_strengths.csv')
df_strengths.head()
# Out:
#    user_id  strength_id_1  strength_id_2  strength_id_3  strength_id_4  \
# 0        1              8              5              2             17
# 1       41              1              2              1              1
# 2       51              0              0              1              2
# 3      151              5              2              0              7
# 4      161              0              0              1              1
#
#    strength_id_5  strength_id_6  strength_id_7  strength_id_8
# 0              9             12              3              8
# 1              1              1              1              1
# 2              0              0              0              2
# 3              1              2              1              4
# 4              0              1              0              0

# %%
# dropping duplicates
df_strengths.drop_duplicates(inplace=True)
df_strengths.dropna(axis=0, inplace=True)

# %%
# Preview
df_strengths[ df_strengths['user_id']==151]
# Out:
#    user_id  strength_id_1  strength_id_2  strength_id_3  strength_id_4  \
# 3      151              5              2              0              7
#
#    strength_id_5  strength_id_6  strength_id_7  strength_id_8
# 3              1              2              1              4

# %% [markdown]
# ### Creating features

# %%
# Dumping userA purposes
temp = df_strengths.add_prefix('userA_').rename(columns={'userA_user_id': 'userA_id'})
df_train = pd.merge(df_train, temp, how='outer', on='userA_id')
#
# Dumping userB purposes
temp = df_strengths.add_prefix('userB_').rename(columns={'userB_user_id': 'userB_id'})
df_train = pd.merge(df_train, temp, how='outer', on='userB_id')

# %%
# Preview of new features
df_train.head()
# Out:
#       from-to  userA_id  userB_id  has_common_skills  n_common_skills  \
# 0  888999-222  888999.0     222.0                0.0             -1.0
# 1         NaN       1.0       NaN                NaN              NaN
# 2         NaN      41.0       NaN                NaN              NaN
# 3         NaN      51.0       NaN                NaN              NaN
# 4         NaN     151.0       NaN                NaN              NaN
#
#    has_common_schools  n_common_schools  has_common_industry  \
# 0                 0.0              -1.0                  0.0
# 1                 NaN               NaN                  NaN
# 2                 NaN               NaN                  NaN
# 3                 NaN               NaN                  NaN
# 4                 NaN               NaN                  NaN
#
#    n_common_industry  has_common_company  ...  userA_strength_id_7  \
# 0               -1.0                 0.0  ...                  NaN
# 1                NaN                 NaN  ...                  3.0
# 2                NaN                 NaN  ...                  1.0
# 3                NaN                 NaN  ...                  0.0
# 4                NaN                 NaN  ...                  1.0
#
#    userA_strength_id_8  userB_strength_id_1  userB_strength_id_2  \
# 0                  NaN                  NaN                  NaN
# 1                  8.0                  NaN                  NaN
# 2                  1.0                  NaN                  NaN
# 3                  2.0                  NaN                  NaN
# 4                  4.0                  NaN                  NaN
#
#    userB_strength_id_3  userB_strength_id_4  userB_strength_id_5  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2                  NaN                  NaN                  NaN
# 3                  NaN                  NaN                  NaN
# 4                  NaN                  NaN                  NaN
#
#    userB_strength_id_6  userB_strength_id_7  userB_strength_id_8
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2                  NaN                  NaN                  NaN
# 3                  NaN                  NaN                  NaN
# 4                  NaN                  NaN                  NaN
#
# [5 rows x 59 columns]

# %%
# Delaing with missing values
df_train = df_train.dropna(subset=['from-to']).fillna(0)

# %%
# Preview of new features
df_train.head()
# Out:
#       from-to  userA_id  userB_id  has_common_skills  n_common_skills  \
# 0  888999-222  888999.0     222.0                0.0             -1.0
#
#    has_common_schools  n_common_schools  has_common_industry  \
# 0                 0.0              -1.0                  0.0
#
#    n_common_industry  has_common_company  ...  userA_strength_id_7  \
# 0               -1.0                 0.0  ...                  0.0
#
#    userA_strength_id_8  userB_strength_id_1  userB_strength_id_2  \
# 0                  0.0                  0.0                  0.0
#
#    userB_strength_id_3  userB_strength_id_4  userB_strength_id_5  \
# 0                  0.0                  0.0                  0.0
#
#    userB_strength_id_6  userB_strength_id_7  userB_strength_id_8
# 0                  0.0                  0.0                  0.0
#
# [1 rows x 59 columns]

# %% [markdown]
# ---
# Writing to file
# ---

# %%
# Writing to output
df_train.to_csv(constants.OUTPUT_FILE,
                index=False,
                header=True)
